# %%
import sqlite3
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import time
import sys
import unicodedata

pd.options.display.max_columns = None # this will set limit of columns to 500
pd.options.display.max_rows = 10 # this will set limit of columns to 500

# %%
dbfile = r"database_macae.db"
conn = sqlite3.connect(dbfile)

# %%
query = "select * from detalhes_emp"
df = pd.read_sql(query, conn)

# %%
df[(df.credor.str.contains('CAIXA ECONOMICA FEDERAL'))].sort_index(axis=1)
# Out:
#                                       ação_de_governo   ano ano_referencia  \
# 4099    168 - Manutenção de Serviços Administrativos  Ano:           2015
# 4100    168 - Manutenção de Serviços Administrativos  Ano:           2015
# 4101    168 - Manutenção de Serviços Administrativos  Ano:           2015
# 4102  14 - Ampliação e melhoria da rede de Ilumina...  Ano:           2015
# 4103    168 - Manutenção de Serviços Administrativos  Ano:           2015
# ...                                                 ...   ...            ...
# 4200    50 - Manutenção dos Serviços Administrativos  2019           2019
# 4201     70 - Urbanização da Nova Esperança - PAC-II  2019           2019
# 4202    50 - Manutenção dos Serviços Administrativos  2019           2019
# 4203    50 - Manutenção dos Serviços Administrativos  2019           2019
# 4204                77 - Trabalho Técnico Social - TTS  2019           2019
#
#        anulado     atualizado_em categoria    categoria_econômica  \
# 4099   R$ 0,00  04/05/2020 23:52     Comum  3 - DESPESAS CORRENTES
# 4100   R$ 0,00  04/05/2020 23:52     Comum  3 - DESPESAS CORRENTES
# 4101   R$ 0,00  04/05/2020 23:52     Comum  3 - DESPESAS CORRENTES
# 4102  R$ 42,80  04/05/2020 23:53     Comum  3 - DESPESAS CORRENTES
# 4103   R$ 0,00  04/05/2020 23:52     Comum  3 - DESPESAS CORRENTES
# ...        ...               ...       ...                     ...
# 4200   R$ 0,00  20/04/2020 00:46     Comum  3 - DESPESAS CORRENTES
# 4201   R$ 0,00  20/04/2020 00:46     Comum  3 - DESPESAS CORRENTES
# 4202   R$ 0,00  20/04/2020 00:46     Comum  3 - DESPESAS CORRENTES
# 4203   R$ 0,00  20/04/2020 00:45     Comum  3 - DESPESAS CORRENTES
# 4204   R$ 0,00  20/04/2020 00:46     Comum  3 - DESPESAS CORRENTES
#
#                 cnpj/cpf contrato convênio                       credor  \
# 4099  00.360.305/0001-04     None      None      CAIXA ECONOMICA FEDERAL
# 4100  00.360.305/0001-04     None      None      CAIXA ECONOMICA FEDERAL
# 4101  00.360.305/0001-04     None      None      CAIXA ECONOMICA FEDERAL
# 4102  00.360.305/0001-04     None      None      CAIXA ECONOMICA FEDERAL
# 4103  00.360.305/0001-04     None      None      CAIXA ECONOMICA FEDERAL
# ...                  ...      ...       ...                          ...
# 4200  00.360.305/0001-04     None      None  CAIXA ECONOMICA FEDERAL S/A
# 4201  00.360.305/0001-04     None      None  CAIXA ECONOMICA FEDERAL S/A
# 4202  00.360.305/0001-04     None      None  CAIXA ECONOMICA FEDERAL S/A
# 4203  00.360.305/0001-04     None      None  CAIXA ECONOMICA FEDERAL S/A
# 4204  00.360.305/0001-04     None      None  CAIXA ECONOMICA FEDERAL S/A
#
#      data_de_homologação data_emissão_empenho  \
# 4099                  None           30/09/2015
# 4100                  None           30/09/2015
# 4101                  None           30/09/2015
# 4102                  None           31/08/2015
# 4103                  None           30/10/2015
# ...                    ...                  ...
# 4200            18/04/2019           18/04/2019
# 4201                  None           07/02/2019
# 4202            22/07/2019           22/07/2019
# 4203            22/07/2019           22/07/2019
# 4204                  None           24/01/2019
#
#                                desdobramento_da_despesa detalhamento_da_fonte  \
# 4099  3.3.90.39.99.99. - OUTROS SERVIÇOS TERC. P.J....                   0 -
# 4100  3.3.90.39.99.99. - OUTROS SERVIÇOS TERC. P.J....                   0 -
# 4101  3.3.90.39.99.99. - OUTROS SERVIÇOS TERC. P.J....                   0 -
# 4102  3.3.90.39.99.99. - OUTROS SERVIÇOS TERC. P.J....                   0 -
# 4103  3.3.90.39.99.99. - OUTROS SERVIÇOS TERC. P.J....                   0 -
# ...                                                 ...                   ...
# 4200   3.3.90.39.39 - ENCARGOS FINANCEIROS INDEDUTIVEIS                   0 -
# 4201                                               None                   0 -
# 4202                  3.3.90.92.81 - SERVICOS BANCARIOS                   0 -
# 4203                  3.3.90.92.81 - SERVICOS BANCARIOS                   0 -
# 4204         3.3.90.92.93 - INDENIZACOES E RESTITUICOES                   0 -
#
#      em_liquidação        empenhado  esfera  \
# 4099         R$ 0,00         R$ 42,80  Fiscal
# 4100         R$ 0,00         R$ 42,80  Fiscal
# 4101         R$ 0,00         R$ 42,80  Fiscal
# 4102         R$ 0,00         R$ 42,80  Fiscal
# 4103         R$ 0,00         R$ 42,80  Fiscal
# ...              ...              ...     ...
# 4200         R$ 0,00      R$ 1.122,66  Fiscal
# 4201         R$ 0,00  R$ 1.900.000,00  Fiscal
# 4202         R$ 0,00      R$ 7.540,10  Fiscal
# 4203         R$ 0,00      R$ 6.819,75  Fiscal
# 4204         R$ 0,00     R$ 49.266,14  Fiscal
#
#                      fonte_de_recursos             função  \
# 4099  ROYALTIES ATÉ 5% - LEI 7.990/89       15 - Urbanismo
# 4100  ROYALTIES ATÉ 5% - LEI 7.990/89       15 - Urbanismo
# 4101  ROYALTIES ATÉ 5% - LEI 7.990/89       15 - Urbanismo
# 4102  ROYALTIES ATÉ 5% - LEI 7.990/89       15 - Urbanismo
# 4103  ROYALTIES ATÉ 5% - LEI 7.990/89       15 - Urbanismo
# ...                                ...                  ...
# 4200  ROYALTIES ATÉ 5% - LEI 7.990/89  4 - Administração
# 4201                Fonte de Recursos:       15 - Urbanismo
# 4202  ROYALTIES ATÉ 5% - LEI 7.990/89  4 - Administração
# 4203  ROYALTIES ATÉ 5% - LEI 7.990/89  4 - Administração
# 4204                        CONVÊNIOS     16 - Habitação
#
#                        grupo_da_despesa    ie          licitação  \
# 4099    3.3 - OUTRAS DESPESAS CORRENTES  None  Dispensa por Limite
# 4100    3.3 - OUTRAS DESPESAS CORRENTES  None  Dispensa por Limite
# 4101    3.3 - OUTRAS DESPESAS CORRENTES  None  Dispensa por Limite
# 4102    3.3 - OUTRAS DESPESAS CORRENTES  None  Dispensa por Limite
# 4103    3.3 - OUTRAS DESPESAS CORRENTES  None  Dispensa por Limite
# ...                                 ...   ...                  ...
# 4200    3.3 - OUTRAS DESPESAS CORRENTES  None       Não se Aplica
# 4201  3.2 - JUROS E ENCARGOS DA DÍVIDA  None       Não se Aplica
# 4202    3.3 - OUTRAS DESPESAS CORRENTES  None       Não se Aplica
# 4203    3.3 - OUTRAS DESPESAS CORRENTES  None       Não se Aplica
# 4204    3.3 - OUTRAS DESPESAS CORRENTES  None    Tomada de Preços
#
#             liquidado      modalidade_de_aplicação  \
# 4099         R$ 42,80  3.3.90 - Aplicações Diretas
# 4100         R$ 42,80  3.3.90 - Aplicações Diretas
# 4101         R$ 42,80  3.3.90 - Aplicações Diretas
# 4102          R$ 0,00  3.3.90 - Aplicações Diretas
# 4103         R$ 42,80  3.3.90 - Aplicações Diretas
# ...               ...                            ...
# 4200      R$ 1.122,66  3.3.90 - Aplicações Diretas
# 4201  R$ 1.878.299,59  3.2.90 - Aplicações Diretas
# 4202      R$ 7.540,10  3.3.90 - Aplicações Diretas
# 4203      R$ 6.819,75  3.3.90 - Aplicações Diretas
# 4204     R$ 49.266,14  3.3.90 - Aplicações Diretas
#
#                                     natureza_da_despesa  \
# 4099  3.3.90.39 - OUTROS SERVIÇOS DE TERCEIROS - PE...
# 4100  3.3.90.39 - OUTROS SERVIÇOS DE TERCEIROS - PE...
# 4101  3.3.90.39 - OUTROS SERVIÇOS DE TERCEIROS - PE...
# 4102  3.3.90.39 - OUTROS SERVIÇOS DE TERCEIROS - PE...
# 4103  3.3.90.39 - OUTROS SERVIÇOS DE TERCEIROS - PE...
# ...                                                 ...
# 4200  3.3.90.39 - OUTROS SERVIÇOS DE TERCEIROS - PE...
# 4201  3.2.90.22 - OUTROS ENCARGOS SOBRE A DÍVIDA PO...
# 4202     3.3.90.92 - DESPESAS DE EXERCÍCIOS ANTERIORES
# 4203     3.3.90.92 - DESPESAS DE EXERCÍCIOS ANTERIORES
# 4204     3.3.90.92 - DESPESAS DE EXERCÍCIOS ANTERIORES
#
#      número_da_licitação  número_do_empenho  \
# 4099                   None               89.0
# 4100                   None               90.0
# 4101                   None               91.0
# 4102                   None               88.0
# 4103                   None               96.0
# ...                     ...                ...
# 4200               16173/19              981.0
# 4201                 405/19              556.0
# 4202                1494/19             1537.0
# 4203                1499/19             1531.0
# 4204                3309/19              363.0
#
#                                      órgão             pago  \
# 4099                    GABINETE DO PREFEITO         R$ 42,80
# 4100                    GABINETE DO PREFEITO         R$ 42,80
# 4101                    GABINETE DO PREFEITO         R$ 42,80
# 4102                    GABINETE DO PREFEITO          R$ 0,00
# 4103                    GABINETE DO PREFEITO         R$ 42,80
# ...                                      ...              ...
# 4200  SECRETARIA MUNICIPAL DE INFRAESTRUTURA      R$ 1.122,66
# 4201  SECRETARIA MUNICIPAL DE INFRAESTRUTURA  R$ 1.878.299,59
# 4202         SECRETARIA MUNICIPAL DE FAZENDA      R$ 7.540,10
# 4203         SECRETARIA MUNICIPAL DE FAZENDA      R$ 6.819,75
# 4204  SECRETARIA MUNICIPAL DE INFRAESTRUTURA     R$ 49.266,14
#
#                 período processo_administrativo   processo_da_compra  \
# 4099  Janeiro a Dezembro                      /0  Processo da Compra:
# 4100  Janeiro a Dezembro                      /0  Processo da Compra:
# 4101  Janeiro a Dezembro                      /0  Processo da Compra:
# 4102  Janeiro a Dezembro                      /0  Processo da Compra:
# 4103  Janeiro a Dezembro                      /0  Processo da Compra:
# ...                  ...                     ...                  ...
# 4200  Janeiro a Dezembro                      /0               0/2019
# 4201  Janeiro a Dezembro                      /0  Processo da Compra:
# 4202  Janeiro a Dezembro                      /0               0/2019
# 4203  Janeiro a Dezembro                      /0               0/2019
# 4204  Janeiro a Dezembro                      /0  Processo da Compra:
#
#                                     programa_de_governo  \
# 4099                        53 - GESTÃO ADMINISTRATIVA
# 4100                        53 - GESTÃO ADMINISTRATIVA
# 4101                        53 - GESTÃO ADMINISTRATIVA
# 4102                         74 - ILUMINAÇÃO PÚBLICA
# 4103                        53 - GESTÃO ADMINISTRATIVA
# ...                                                 ...
# 4200                        33 - GESTÃO ADMINISTRATIVA
# 4201  3 - AMPLIAÇÃO, MELHORIA E MODERNIZAÇÃO DA ...
# 4202                        33 - GESTÃO ADMINISTRATIVA
# 4203                        33 - GESTÃO ADMINISTRATIVA
# 4204                                 45 - HABITAR LEGAL
#
#                        subfunção    tipo_empenho  \
# 4099   122 - Administração Geral  Orçamentário
# 4100   122 - Administração Geral  Orçamentário
# 4101   122 - Administração Geral  Orçamentário
# 4102  451 - Infra-Estrutura Urbana  Orçamentário
# 4103   122 - Administração Geral  Orçamentário
# ...                            ...             ...
# 4200   122 - Administração Geral  Orçamentário
# 4201  451 - Infra-estrutura Urbana  Orçamentário
# 4202   122 - Administração Geral  Orçamentário
# 4203   122 - Administração Geral  Orçamentário
# 4204      482 - Habitação Urbana  Orçamentário
#
#                                     unidade  \
# 4099  Empresa Mun. de Iluminação Pública
# 4100  Empresa Mun. de Iluminação Pública
# 4101  Empresa Mun. de Iluminação Pública
# 4102  Empresa Mun. de Iluminação Pública
# 4103  Empresa Mun. de Iluminação Pública
# ...                                     ...
# 4200             Sec. Mun. Adjunta de Obras
# 4201       Sec. Mun. Adjunta de Habitação
# 4202        Secretaria Municipal de Fazenda
# 4203        Secretaria Municipal de Fazenda
# 4204       Sec. Mun. Adjunta de Habitação
#
#                          unidade_gestora valor_anulado valor_em_liquidação  \
# 4099  EMPRESA MUN. ILUMIN. PÚBLICA -0014       R$ 0,00             R$ 0,00
# 4100  EMPRESA MUN. ILUMIN. PÚBLICA -0014       R$ 0,00             R$ 0,00
# 4101  EMPRESA MUN. ILUMIN. PÚBLICA -0014       R$ 0,00             R$ 0,00
# 4102  EMPRESA MUN. ILUMIN. PÚBLICA -0014      R$ 42,80             R$ 0,00
# 4103  EMPRESA MUN. ILUMIN. PÚBLICA -0014       R$ 0,00             R$ 0,00
# ...                                  ...           ...                 ...
# 4200          PREFEITURA DE MACAÉ - 0000       R$ 0,00             R$ 0,00
# 4201          PREFEITURA DE MACAÉ - 0000       R$ 0,00             R$ 0,00
# 4202          PREFEITURA DE MACAÉ - 0000       R$ 0,00             R$ 0,00
# 4203          PREFEITURA DE MACAÉ - 0000       R$ 0,00             R$ 0,00
# 4204          PREFEITURA DE MACAÉ - 0000       R$ 0,00             R$ 0,00
#
#       valor_empenhado  valor_liquidado       valor_pago
# 4099         R$ 42,80         R$ 42,80         R$ 42,80
# 4100         R$ 42,80         R$ 42,80         R$ 42,80
# 4101         R$ 42,80         R$ 42,80         R$ 42,80
# 4102         R$ 42,80          R$ 0,00          R$ 0,00
# 4103         R$ 42,80         R$ 42,80         R$ 42,80
# ...               ...              ...              ...
# 4200      R$ 1.122,66      R$ 1.122,66      R$ 1.122,66
# 4201  R$ 1.900.000,00  R$ 1.878.299,59  R$ 1.878.299,59
# 4202      R$ 7.540,10      R$ 7.540,10      R$ 7.540,10
# 4203      R$ 6.819,75      R$ 6.819,75      R$ 6.819,75
# 4204     R$ 49.266,14     R$ 49.266,14     R$ 49.266,14
#
# [106 rows x 43 columns]

# %%
# test_emp_new = pd.read_csv('./raw_data/credores_empenhos_2015 BACKUP.csv')
test_emp_new = pd.read_csv('./raw_data/detalhes_emp_2019.csv')

# %%
det_emp = ['detalhes_emp_2015.csv',
           'detalhes_emp_2016.csv',
           'detalhes_emp_2017.csv',
           'detalhes_emp_2018.csv',
           'detalhes_emp_2019.csv']
detalhes_emp_list = []
for i in det_emp:
    file = './raw_data/' + str(i)
    df = pd.read_csv(file)
    df['ano_referencia'] = i.split('.')[0][-4:]
    df = df.iloc[df['Credor'].str.normalize('NFKD').argsort()]  # sort columns containing special chars
    detalhes_emp_list.append(df)

detalhes_emp = pd.concat(detalhes_emp_list, sort=True).drop_duplicates()
detalhes_emp = detalhes_emp.sort_index(axis=1)
detalhes_emp = detalhes_emp.loc[:,'Ação de Governo':]

# %%
detalhes_emp = detalhes_emp[['data_emissão_empenho', 'número_do_empenho', 'unidade_gestora',
                             'credor', 'cnpj/cpf', 'valor_empenhado', 'valor_em_liquidação', 'valor_liquidado',
                             'valor_pago', 'valor_anulado', 'atualizado_em', 'período', 'ano',
                             'unidade_gestora.1', 'número_empenho', 'tipo_empenho', 'categoria',
                             'órgão', 'unidade', 'função', 'subfunção', 'programa_de_governo',
                             'ação_de_governo', 'esfera', 'categoria_econômica', 'grupo_da_despesa',
                             'modalidade_de_aplicação', 'natureza_da_despesa', 'desdobramento_da_despesa',
                             'fonte_de_recursos', 'detalhamento_da_fonte', 'credor.1', 'licitação',
                             'número_da_licitação', 'data_de_homologação', 'processo_da_compra',
                             'processo_administrativo', 'contrato', 'convênio', 'empenhado', 'em_liquidação',
                             'liquidado', 'pago', 'anulado', 'ano_referencia']]

# %%
# test_emp_new['len'] = test_emp_new['detalhe_empenho'].apply(lambda x: len(str(x)))
test_emp_new.sort_index(axis=1).loc[:,'Ação de Governo':]
# Out:
#                                       Ação de Governo   Ano    Anulado  \
# 0              133 - Concessao de Benefícios Eventuais  2019    R$ 0,00
# 1                                                   NaN  Ano:    R$ 0,00
# 2       50 - Manutenção dos Serviços Administrativos  Ano:    R$ 0,00
# 3     68 - Manutenção do Programa Municipal Dinhei...  2019    R$ 0,00
# 4     68 - Manutenção do Programa Municipal Dinhei...  2019    R$ 0,00
# ...                                                 ...   ...        ...
# 5526                       11 - Auxílio Aluguel-Social  2019    R$ 0,00
# 5527    50 - Manutenção dos Serviços Administrativos  2019    R$ 0,00
# 5528            23 - Realização de Eventos Esportivos  2019  R$ 864,00
# 5529    50 - Manutenção dos Serviços Administrativos  Ano:    R$ 0,00
# 5530    50 - Manutenção dos Serviços Administrativos  Ano:    R$ 0,00
#
#          Atualizado em               Categoria     Categoria Econômica  \
# 0     19/04/2020 18:12                   Comum   3 - DESPESAS CORRENTES
# 1     19/04/2020 18:12                   Comum                      NaN
# 2     19/04/2020 18:13                   Comum   3 - DESPESAS CORRENTES
# 3     19/04/2020 18:13  Adto-Suprimento Fundos   3 - DESPESAS CORRENTES
# 4     19/04/2020 18:13  Adto-Suprimento Fundos   3 - DESPESAS CORRENTES
# ...                ...                     ...                      ...
# 5526  21/04/2020 06:17                   Comum   3 - DESPESAS CORRENTES
# 5527  21/04/2020 06:18                   Comum   3 - DESPESAS CORRENTES
# 5528  21/04/2020 06:18                   Comum  4 - DESPESAS DE CAPITAL
# 5529  21/04/2020 06:18                   Comum   3 - DESPESAS CORRENTES
# 5530  21/04/2020 06:18                   Comum   3 - DESPESAS CORRENTES
#
#      Contrato Convênio                                             Credor  \
# 0         NaN       NaN     2 LPM CENTER COMERCIO E DISTRIBUIDORA LTDA EPP
# 1         NaN       NaN    8 AM OFFICE COM & SERV MOVEIS ESCRITORIO EIRELI
# 2         NaN       NaN   A C DOS SANTOS OLIVEIRA COMERCIO E SERVIÇOS LTDA
# 3         NaN       NaN  A. DE A. ES. DO COL. MU. TARCISIO PAES DE FIGU...
# 4         NaN       NaN  A. DE A. ES. DO COL. MU. TARCISIO PAES DE FIGU...
# ...       ...       ...                                                ...
# 5526      NaN       NaN                             ZENILDO LOPES DA SILVA
# 5527      NaN       NaN                    ZTA INSPECOES E SERVICOS EIRELI
# 5528      NaN       NaN                    ZTA INSPECOES E SERVICOS EIRELI
# 5529      NaN       NaN                ZUUM CAR VIDROS DE MACAÉ LTDA - EPP
# 5530      NaN       NaN                ZUUM CAR VIDROS DE MACAÉ LTDA - EPP
#
#                                                Credor.1 Data Emissão Empenho  \
# 0        2 LPM CENTER COMERCIO E DISTRIBUIDORA LTDA EPP           27/06/2019
# 1       8 AM OFFICE COM & SERV MOVEIS ESCRITORIO EIRELI           05/11/2018
# 2     A C DOS SANTOS OLIVEIRA COMERCIO E SERVIÇOS LTDA           17/07/2019
# 3     A. DE A. ES. DO COL. MU. TARCISIO PAES DE FIGU...           11/09/2019
# 4     A. DE A. ES. DO COL. MU. TARCISIO PAES DE FIGU...           11/09/2019
# ...                                                 ...                  ...
# 5526                             ZENILDO LOPES DA SILVA           26/03/2019
# 5527                    ZTA INSPECOES E SERVICOS EIRELI           30/12/2019
# 5528                    ZTA INSPECOES E SERVICOS EIRELI           16/09/2019
# 5529               ZUUM CAR VIDROS DE MACAÉ LTDA - EPP           03/09/2019
# 5530               ZUUM CAR VIDROS DE MACAÉ LTDA - EPP           25/03/2019
#
#      Data de Homologação                           Desdobramento da Despesa  \
# 0               27/06/2019                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN  3.3.90.30.15 - MATERIAL P/ FESTIVIDADES E HOME...
# 3               11/09/2019  3.3.90.30.96 - MATERIAL DE CONSUMO - PAGTO ANT...
# 4               11/09/2019  3.3.90.39.96 - OUTROS SERV.TERC. P.J.- PAGTO A...
# ...                    ...                                                ...
# 5526                   NaN   3.3.90.48.01.05. - AUX. FIN. ALUGUEL EMERGÊNCIA
# 5527                   NaN      3.3.90.30.14 - MATERIAL EDUCATIVO E ESPORTIVO
# 5528            16/09/2019   4.4.90.52.04 - APARELHOS DE MEDICAO E ORIENTACAO
# 5529                   NaN   3.3.90.39.19 - MANUTENCAO E CONSERV. DE VEICULOS
# 5530                   NaN   3.3.90.39.19 - MANUTENCAO E CONSERV. DE VEICULOS
#
#      Detalhamento da Fonte Em Liquidação     Empenhado             Esfera  \
# 0                      0 -         R$ 0,00  R$ 20.599,60  Seguridade Social
# 1                      NaN         R$ 0,00  R$ 24.300,00                NaN
# 2                      0 -         R$ 0,00   R$ 7.900,00             Fiscal
# 3                      0 -         R$ 0,00  R$ 11.016,00             Fiscal
# 4                      0 -         R$ 0,00   R$ 7.344,00             Fiscal
# ...                    ...             ...           ...                ...
# 5526                   0 -         R$ 0,00   R$ 7.001,30  Seguridade Social
# 5527                   0 -         R$ 0,00     R$ 864,00             Fiscal
# 5528                   0 -         R$ 0,00  R$ 17.333,84             Fiscal
# 5529                   0 -         R$ 0,00     R$ 662,00             Fiscal
# 5530                   0 -         R$ 0,00     R$ 662,00             Fiscal
#
#                                       Fonte de Recursos  \
# 0                                    Fonte de Recursos:
# 1                        RECURSOS ORDINÁRIOS - TESOURO
# 2                        RECURSOS ORDINÁRIOS - TESOURO
# 3                        RECURSOS ORDINÁRIOS - TESOURO
# 4                        RECURSOS ORDINÁRIOS - TESOURO
# ...                                                 ...
# 5526                   ROYALTIES ATÉ 5% - LEI 7.990/89
# 5527  ROYALTIES PELO EXCEDENTE DA PRODUÇÃO - LEI 9...
# 5528                   ROYALTIES ATÉ 5% - LEI 7.990/89
# 5529                            CONSERVAÇÃO AMBIENTAL
# 5530                            CONSERVAÇÃO AMBIENTAL
#
#                      Função                 Grupo da Despesa   IE  \
# 0     8 - Assistência Social  3.3 - OUTRAS DESPESAS CORRENTES  NaN
# 1                         NaN                              NaN  NaN
# 2             1 - Legislativa  3.3 - OUTRAS DESPESAS CORRENTES  NaN
# 3             12 - Educação  3.3 - OUTRAS DESPESAS CORRENTES  NaN
# 4             12 - Educação  3.3 - OUTRAS DESPESAS CORRENTES  NaN
# ...                       ...                              ...  ...
# 5526  8 - Assistência Social  3.3 - OUTRAS DESPESAS CORRENTES  NaN
# 5527    27 - Desporto e Lazer  3.3 - OUTRAS DESPESAS CORRENTES  NaN
# 5528    27 - Desporto e Lazer              4.4 - INVESTIMENTOS  NaN
# 5529   18 - Gestão Ambiental  3.3 - OUTRAS DESPESAS CORRENTES  NaN
# 5530   18 - Gestão Ambiental  3.3 - OUTRAS DESPESAS CORRENTES  NaN
#
#               Licitação     Liquidado      Modalidade de Aplicação  \
# 0      Pregão Presencial  R$ 20.599,60  3.3.90 - Aplicações Diretas
# 1      Pregão Presencial  R$ 24.300,00                            NaN
# 2     Dispensa por Limite   R$ 7.900,00  3.3.90 - Aplicações Diretas
# 3          Não se Aplica  R$ 11.016,00  3.3.90 - Aplicações Diretas
# 4          Não se Aplica   R$ 7.344,00  3.3.90 - Aplicações Diretas
# ...                   ...           ...                            ...
# 5526       Não se Aplica   R$ 6.301,17  3.3.90 - Aplicações Diretas
# 5527  Dispensa por Limite       R$ 0,00  3.3.90 - Aplicações Diretas
# 5528  Dispensa por Limite       R$ 0,00  4.4.90 - Aplicações Diretas
# 5529  Dispensa por Limite     R$ 662,00  3.3.90 - Aplicações Diretas
# 5530  Dispensa por Limite     R$ 662,00  3.3.90 - Aplicações Diretas
#
#                                     Natureza da Despesa  No Contrato  \
# 0     3.3.90.32 - MATERIAL, BEM OU SERV. P/ DISTRIB....          NaN
# 1                                                   NaN          NaN
# 2                       3.3.90.30 - MATERIAL DE CONSUMO          NaN
# 3                       3.3.90.30 - MATERIAL DE CONSUMO          NaN
# 4     3.3.90.39 - OUTROS SERVIÇOS DE TERCEIROS - PE...          NaN
# ...                                                 ...          ...
# 5526  3.3.90.48 - OUTROS AUXÍLIOS FINANCEIROS A PES...          NaN
# 5527                    3.3.90.30 - MATERIAL DE CONSUMO          NaN
# 5528     4.4.90.52 - EQUIPAMENTOS E MATERIAL PERMANENTE          NaN
# 5529  3.3.90.39 - OUTROS SERVIÇOS DE TERCEIROS - PE...          NaN
# 5530  3.3.90.39 - OUTROS SERVIÇOS DE TERCEIROS - PE...          NaN
#
#      Nr. Licitação  Número Empenho Número da Licitação  \
# 0                NaN               54               112/2018
# 1            24/2018              157                    NaN
# 2                NaN              123                    NaN
# 3                NaN             1839               42049/19
# 4                NaN             1840               42049/19
# ...              ...              ...                    ...
# 5526             NaN              877                2828/19
# 5527             NaN             2551               35692/19
# 5528             NaN             1877               35692/19
# 5529             NaN               33                    NaN
# 5530             NaN                4                    NaN
#
#       Número do Empenho                                   Órgão  \
# 0                    54  SEC.MUN.DESENV.SOCIAL E DIREITOS HUMANOS
# 1                   157             CÂMARA LEGISLATIVA DE MACAÉ
# 2                   123             CÂMARA LEGISLATIVA DE MACAÉ
# 3                  1839        SECRETARIA MUNICIPAL DE EDUCAÇÃO
# 4                  1840        SECRETARIA MUNICIPAL DE EDUCAÇÃO
# ...                 ...                                       ...
# 5526                877  SEC.MUN.DESENV.SOCIAL E DIREITOS HUMANOS
# 5527               2551           SECRETARIA MUNICIPAL DE ESPORTE
# 5528               1877           SECRETARIA MUNICIPAL DE ESPORTE
# 5529                 33          SECRETARIA MUNICIPAL DE AMBIENTE
# 5530                  4          SECRETARIA MUNICIPAL DE AMBIENTE
#
#               Pago            Período Processo Administrativo  \
# 0     R$ 20.599,60  Janeiro a Dezembro                      /0
# 1     R$ 24.300,00  Janeiro a Dezembro                     NaN
# 2      R$ 7.900,00  Janeiro a Dezembro                      /0
# 3     R$ 11.016,00  Janeiro a Dezembro                      /0
# 4      R$ 7.344,00  Janeiro a Dezembro                      /0
# ...            ...                 ...                     ...
# 5526   R$ 6.301,17  Janeiro a Dezembro                      /0
# 5527       R$ 0,00  Janeiro a Dezembro                      /0
# 5528       R$ 0,00  Janeiro a Dezembro                      /0
# 5529     R$ 662,00  Janeiro a Dezembro                      /0
# 5530     R$ 662,00  Janeiro a Dezembro                      /0
#
#        Processo da Compra                                Programa de Governo  \
# 0        110118/2019/2019                      6 - ASSISTÊNCIA COMUNITÁRIA
# 1                     NaN                                                NaN
# 2     Processo da Compra:                        33 - GESTÃO ADMINISTRATIVA
# 3                  0/2019  66 - UNIVERSALIZAÇÃO DO ATENDIMENTO AO ESCOL...
# 4                  0/2019  66 - UNIVERSALIZAÇÃO DO ATENDIMENTO AO ESCOL...
# ...                   ...                                                ...
# 5526  Processo da Compra:                      6 - ASSISTÊNCIA COMUNITÁRIA
# 5527  Processo da Compra:                        33 - GESTÃO ADMINISTRATIVA
# 5528               0/2019                4 - APOIO E REALIZAÇÃO DE EVENTOS
# 5529  Processo da Compra:                        33 - GESTÃO ADMINISTRATIVA
# 5530  Processo da Compra:                        33 - GESTÃO ADMINISTRATIVA
#
#                           SubFunção    Tipo Empenho  \
# 0     244 - Assistência Comunitária  Orçamentário
# 1                                 NaN  Restos a Pagar
# 2             31 - Ação Legislativa  Orçamentário
# 3            361 - Ensino Fundamental  Orçamentário
# 4            361 - Ensino Fundamental  Orçamentário
# ...                               ...             ...
# 5526  244 - Assistência Comunitária  Orçamentário
# 5527      122 - Administração Geral  Orçamentário
# 5528          392 - Difusão Cultural  Orçamentário
# 5529      122 - Administração Geral  Orçamentário
# 5530      122 - Administração Geral  Orçamentário
#
#                                        Unidade  \
# 0       Fundo Municipal de Assistência Social
# 1                        Secretaria da Câmara
# 2                        Secretaria da Câmara
# 3      Sec. Mun. Adjunta de Educação Básica
# 4      Sec. Mun. Adjunta de Educação Básica
# ...                                        ...
# 5526  Sec. Mun. Desen. Social Dir. Hum Acessib
# 5527           Secretaria Municipal de Esporte
# 5528           Secretaria Municipal de Esporte
# 5529                           Fundo Ambiental
# 5530                           Fundo Ambiental
#
#                           Unidade Gestora  \
# 0     FUNDO MUN. DE ASSIST. SOCIAL - 0023
# 1      CÂMARA LEGISLATIVA DE MACAÉ - 0001
# 2      CÂMARA LEGISLATIVA DE MACAÉ - 0001
# 3              PREFEITURA DE MACAÉ - 0000
# 4              PREFEITURA DE MACAÉ - 0000
# ...                                   ...
# 5526           PREFEITURA DE MACAÉ - 0000
# 5527           PREFEITURA DE MACAÉ - 0000
# 5528           PREFEITURA DE MACAÉ - 0000
# 5529               FUNDO AMBIENTAL - 0022
# 5530               FUNDO AMBIENTAL - 0022
#
#                          Unidade Gestora.1 Valor Anulado Valor Em Liquidação  \
# 0      FUNDO MUN. DE ASSIST. SOCIAL - 0023       R$ 0,00             R$ 0,00
# 1     CÂMARA LEGISLATIVA DE MACAÉ - 0001       R$ 0,00             R$ 0,00
# 2     CÂMARA LEGISLATIVA DE MACAÉ - 0001       R$ 0,00             R$ 0,00
# 3              PREFEITURA DE MACAÉ - 0000       R$ 0,00             R$ 0,00
# 4              PREFEITURA DE MACAÉ - 0000       R$ 0,00             R$ 0,00
# ...                                    ...           ...                 ...
# 5526           PREFEITURA DE MACAÉ - 0000       R$ 0,00             R$ 0,00
# 5527           PREFEITURA DE MACAÉ - 0000       R$ 0,00             R$ 0,00
# 5528           PREFEITURA DE MACAÉ - 0000     R$ 864,00             R$ 0,00
# 5529                FUNDO AMBIENTAL - 0022       R$ 0,00             R$ 0,00
# 5530                FUNDO AMBIENTAL - 0022       R$ 0,00             R$ 0,00
#
#      Valor Empenhado Valor Liquidado    Valor Pago  \
# 0       R$ 20.599,60    R$ 20.599,60  R$ 20.599,60
# 1       R$ 24.300,00    R$ 24.300,00  R$ 24.300,00
# 2        R$ 7.900,00     R$ 7.900,00   R$ 7.900,00
# 3       R$ 11.016,00    R$ 11.016,00  R$ 11.016,00
# 4        R$ 7.344,00     R$ 7.344,00   R$ 7.344,00
# ...              ...             ...           ...
# 5526     R$ 7.001,30     R$ 6.301,17   R$ 6.301,17
# 5527       R$ 864,00         R$ 0,00       R$ 0,00
# 5528    R$ 17.333,84         R$ 0,00       R$ 0,00
# 5529       R$ 662,00       R$ 662,00     R$ 662,00
# 5530       R$ 662,00       R$ 662,00     R$ 662,00
#
#                                         detalhe_empenho
# 0     <table cellpadding="1px" cellspacing="0px" cla...
# 1     <table cellpadding="1px" cellspacing="0px" cla...
# 2     <table cellpadding="1px" cellspacing="0px" cla...
# 3     <table cellpadding="1px" cellspacing="0px" cla...
# 4     <table cellpadding="1px" cellspacing="0px" cla...
# ...                                                 ...
# 5526  <table cellpadding="1px" cellspacing="0px" cla...
# 5527  <table cellpadding="1px" cellspacing="0px" cla...
# 5528  <table cellpadding="1px" cellspacing="0px" cla...
# 5529  <table cellpadding="1px" cellspacing="0px" cla...
# 5530  <table cellpadding="1px" cellspacing="0px" cla...
#
# [5531 rows x 47 columns]

# %%
test_emp_new[(test_emp_new.Credor=='CAIXA ECONOMICA FEDERAL')&(test_emp_new['Número do Empenho']==70)]
# Out:
#                        Credor Data Emissão Empenho  Número do Empenho  \
# 1438  CAIXA ECONOMICA FEDERAL           25/05/2015                 70
# 1452  CAIXA ECONOMICA FEDERAL           25/05/2015                 70
#
#                          Unidade Gestora Valor Anulado Valor Em Liquidação  \
# 1438  EMPRESA MUN. ILUMIN. PÚBLICA -0014       R$ 0,00             R$ 0,00
# 1452  EMPRESA MUN. ILUMIN. PÚBLICA -0014       R$ 0,00             R$ 0,00
#
#      Valor Empenhado Valor Liquidado Valor Pago  \
# 1438       R$ 123,02       R$ 123,02  R$ 123,02
# 1452       R$ 123,02       R$ 123,02  R$ 123,02
#
#                                         detalhe_empenho   len
# 1438  <table cellpadding="1px" cellspacing="0px" cla...  4862
# 1452  <table cellpadding="1px" cellspacing="0px" cla...  4862

# %%
def parse(table):
    rows = table.find_all('tr')
    key_name = 0
    key_value = 0
    keys_list = []
    keys_values = []

    for i in rows:
        for j in i.find_all('td'):
            if j.text:
                text = str(j.text.strip())
                content = unicodedata.normalize("NFKD", text)

                if key_name == 1 and key_value==0:
                    key_value = 1
                    key_value_text = content.strip()
                if ":" in content and "/" not in content:
                    if content[-1] == ":":
                        key_name = 1
                        key_name_text = content[:-1].strip()
                    else:
                        key_name = 1
                        key_value = 1
                        key_name_text = content.split(":")[0].strip()
                        key_value_text = content.split(":")[1].strip()
                if key_value == 1 and key_name == 1:
                    key_value = 0
                    key_name = 0
                    keys_list.append(key_name_text)
                    keys_values.append(key_value_text)
                    
    keys_and_values = zip(keys_list, keys_values)
    values_dict = dict(keys_and_values)
    detalhes_emp = pd.DataFrame.from_dict(values_dict, orient='index').T
    return detalhes_emp

# %%
appended_list = []

for i in lista_empenhos:
    emp = str(i)
    soup = BeautifulSoup(emp, 'html.parser')
    table = soup.find('table')
    det_empenho_df = parse(table)
    appended_list.append(det_empenho_df)
